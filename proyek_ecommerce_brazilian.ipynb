# %% [markdown]
# <a href="https://colab.research.google.com/github/miaamelia12/proyek-ecommerce-brazilian/blob/main/proyek_ecommerce_brazilian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Ecommerce Brazilian
# - Nama: Fahmia Amelia
# - Email: miaamelia940@gmail.com
# - Id Dicoding: fahmiaamelia

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis
# - Bagaimana performa penjualan dan revenue perusahaan dalam bulan terakhir?
# - Berapa banyak uang yang dihabiskan pelanggan dalam berapa bulan terakhir?

# %% [markdown]
# ## Menyiapkan semua library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv("geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv("order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_payments_df = pd.read_csv("order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv("order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
orders_df = pd.read_csv("orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
product_category_name_translation_df = pd.read_csv("product_category_name_translation.csv")
product_category_name_translation_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv("products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
sellers_df = pd.read_csv("sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# # Assessing Data

# %% [markdown]
# ### Menilai tabel `customers_df`

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers_df.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
customers_df.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ### Menilai tabel `geolocation_df`

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
geolocation_df.nunique()
# Out:
# geolocation_zip_code_prefix     19015
# geolocation_lat                717360
# geolocation_lng                717613
# geolocation_city                 8011
# geolocation_state                  27
# dtype: int64

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  261831

# %%
geolocation_df.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# ### Menilai tabel `order_items_df`

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
order_items_df.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Menilai tabel `order_payments_df`

# %%
order_payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_payments_df.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
order_payments_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# ### Menilai tabel `order_reviews_df`

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
print("jumlah duplikasi: ", order_reviews_df.duplicated().sum())
order_reviews_df.describe()
# Out:
# jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# ### Menilai tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders_df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 23:38:46
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# ## Menilai tabel `product_category_name_translation_df`

# %%
product_category_name_translation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
product_category_name_translation_df.nunique()
# Out:
# product_category_name            71
# product_category_name_english    71
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_category_name_translation_df.duplicated().sum())
product_category_name_translation_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ### Menilai tabel `products_df`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %% [markdown]
# ### Menilai tabel `sellers_df`

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
sellers_df.nunique()
# Out:
# seller_id                 3095
# seller_zip_code_prefix    2246
# seller_city                611
# seller_state                23
# dtype: int64

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Membersihkan tabel `geolocation_df`

# %% [markdown]
# #### Duplicate data

# %%
geolocation_df.duplicated().sum()
# Out:
# 261831

# %%
geo_df_duplicate = geolocation_df.duplicated()
geolocation_df[geo_df_duplicate]
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# 44             sao paulo                SP
# 65             sao paulo                SP
# 66             sao paulo                SP
# 67             sao paulo                SP
# ...                  ...               ...
# 1000153          ciriaco                RS
# 1000154         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000162         tapejara                RS
#
# [261831 rows x 5 columns]

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ## Membersihkan tabel `order_items_df`

# %% [markdown]
# ### Memperbaiki tipe data

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
shipping_date = ["shipping_limit_date"]

for column in shipping_date:
    order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# 4 2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ## Membersihkan tabel `order_reviews_df`

# %% [markdown]
# ### Memperbaiki tipe data

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
order_review_date = ["review_creation_date", "review_answer_timestamp"]

for column in order_review_date:
    order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN           2018-01-18
# 1                                                NaN           2018-03-10
# 2                                                NaN           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ## Membersihkan tabel `orders_df`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_date = ["order_purchase_timestamp", "order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"]

for column in order_date:
    orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0                    2017-10-18
# 1                    2018-08-13
# 2                    2018-09-04
# 3                    2017-12-15
# 4                    2018-02-26

# %% [markdown]
# ## Membersihkan tabel `products_df`

# %%
products_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# 128                    NaN                         NaN                 NaN
# 145                    NaN                         NaN                 NaN
# 154                    NaN                         NaN                 NaN
# 197                    NaN                         NaN                 NaN
# ...                    ...                         ...                 ...
# 32515                  NaN                         NaN                 NaN
# 32589                  NaN                         NaN                 NaN
# 32616                  NaN                         NaN                 NaN
# 32772                  NaN                         NaN                 NaN
# 32852                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 105               650.0               17.0               14.0
# 128               300.0               16.0                7.0
# 145               200.0               20.0               20.0
# 154             18500.0               41.0               30.0
# 197               300.0               35.0                7.0
# ...                 ...                ...                ...
# 32515            1800.0               30.0               20.0
# 32589             800.0               30.0               10.0
# 32616             200.0               21.0                8.0
# 32772            1300.0               45.0               16.0
# 32852             700.0               28.0                3.0
#
#        product_width_cm
# 105                12.0
# 128                20.0
# 145                20.0
# 154                41.0
# 197                12.0
# ...                 ...
# 32515              70.0
# 32589              23.0
# 32616              16.0
# 32772              45.0
# 32852              43.0
#
# [610 rows x 9 columns]

# %%
products_df.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
products_df.fillna(value="cama_mesa_banho", inplace=True)

# %%
products_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore `customers_df`

# %%
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 78185  b3b02ff03c556839d91070f207188bdd  4ccb9e4180e8b01c2fbe9b1965929260
# 3048   8ebb5bcb13deec1375db0fc1bea402fb  f0bc14cc2b1c0f7f28e790bd4d016a7d
# 71815  a8fe1687220aeb4547efe4bcdb5a8332  b626a79abc5f77723f7434fcfd515b91
# 73402  a322a6a643ad00260fbf07da3f0f2bb7  384a8e41b65b0f4bb086437412842c1c
# 6432   51478fa6f626871ba9023c80585e4952  c72e291ccf98df8df8bdc3fcadf64f35
#
#        customer_zip_code_prefix  customer_city customer_state
# 78185                     78580  alta floresta             MT
# 3048                      11025         santos             SP
# 71815                     18053       sorocaba             SP
# 73402                     11717   praia grande             SP
# 6432                      32143       contagem             MG

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore `geolocation_df`

# %%
geolocation_df.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 382627                        18170       -23.719435       -47.407758
# 815734                        76901       -10.872170       -61.971932
# 697468                        46860       -12.770574       -40.214057
# 738101                        59540        -5.758578       -36.004043
# 682566                        43900       -12.626813       -38.678171
#
#                geolocation_city geolocation_state
# 382627                  piedade                SP
# 815734                ji-paraná                RO
# 697468                     iacu                BA
# 738101  caicara do rio do vento                RN
# 682566   sao francisco do conde                BA

# %%
geolocation_df.groupby(by="geolocation_city").geolocation_zip_code_prefix.nunique().sort_values(ascending=False)
# Out:
# geolocation_city
# sao paulo               3171
# são paulo               3013
# brasilia                 496
# brasília                 406
# rio de janeiro           404
#                         ...
# guarei                     1
# guardinha                  1
# guarda-mor                 1
# guarda dos ferreiros       1
# óleo                       1
# Name: geolocation_zip_code_prefix, Length: 8011, dtype: int64

# %%
geolocation_df.groupby(by="geolocation_state").geolocation_zip_code_prefix.nunique().sort_values(ascending=False)
# Out:
# geolocation_state
# SP    6349
# MG    1868
# RJ    1390
# RS    1132
# PR    1046
# BA     992
# GO     773
# SC     620
# PE     596
# CE     548
# DF     516
# PB     324
# ES     315
# MA     313
# PA     309
# PI     307
# RN     280
# MT     254
# MS     242
# TO     184
# AL     178
# AM     144
# SE     135
# RO     108
# AC      46
# RR      28
# AP      26
# Name: geolocation_zip_code_prefix, dtype: int64

# %% [markdown]
# ### Explore `order_items_df`

# %%
order_items_df.sample(10)
# Out:
#                                 order_id  order_item_id  \
# 92188   d131625abf3dd1daa6fd04443cbc6729              1
# 100036  e2e415b0eca67d98cf1b6fb11336025a              1
# 94308   d5cbbe1602100752cd72f9630321613d              1
# 64684   93c9e800268063cefb7efac3c9025276              1
# 60638   8a37cae0305cc1e69d6f5d0629719e9a              1
# 96784   dba140d12592fdc150bbeed0f7f1a32e              1
# 668     0191b6a5a70bcbc6cdd39427f216602e              1
# 106037  f0fc205cd844540932464d058cb08aa7              1
# 63714   917a1e55e47868301492b1f8f765a6f8              1
# 5937    0d74a4953206657c77bf6952c432809b              1
#
#                               product_id                         seller_id  \
# 92188   368c6c730842d78016ad823897a372db  1f50f920176fa81dab994f9023523100
# 100036  254104e9110b124bab38acfa269fb764  4a3ccda38b2129705f3fb522db62ca31
# 94308   deafa3faa1b80a845f4fbfb3ffa5d0b8  b2ba3715d723d245138f291a6fe42594
# 64684   7d3297b1d734f63d40632fcf8e1a2cec  ea8482cd71df3c1969d7b9473ff13abc
# 60638   57f2bc497c1a3ebe41ba7a06d78ed159  6560211a19b47992c3666cc44a7e94c0
# 96784   e7bbc0d43d1f5cb09bab95b664236633  897060da8b9a21f655304d50fd935913
# 668     9c98b59719a74f32903537bc5c9262ce  acce39e832338debb07b02385cde5967
# 106037  6ba4f83d1c821bb17fe0a917881258d4  7dc8c42cc750eeafea6c85712ffee9bf
# 63714   c1f5307decb89342351bec53668cffd9  ea8482cd71df3c1969d7b9473ff13abc
# 5937    4e2e67ecbe3c5465a6c3c76db8acba86  cbd996ad3c1b7dc71fd0e5f5df9087e2
#
#        shipping_limit_date   price  freight_value
# 92188  2017-12-12 02:49:56   59.00          19.65
# 100036 2017-12-19 20:29:23  245.90          14.74
# 94308  2018-01-11 12:09:08  232.90          16.39
# 64684  2017-11-20 11:50:20   24.99          11.85
# 60638  2018-04-17 13:50:35   55.00          18.27
# 96784  2018-01-17 07:26:09   49.00          16.11
# 668    2018-08-24 09:55:20  139.90          27.96
# 106037 2017-11-23 20:46:42  699.99          40.56
# 63714  2018-02-01 19:18:19   29.99           7.78
# 5937   2017-03-29 16:21:18   23.99          14.52

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.705124
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  6560211a19b47992c3666cc44a7e94c0
# freq                                 527                              2033
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#                   shipping_limit_date          price  freight_value
# count                          112650  112650.000000  112650.000000
# unique                            NaN            NaN            NaN
# top                               NaN            NaN            NaN
# freq                              NaN            NaN            NaN
# mean    2018-01-07 15:36:52.192685312     120.653739      19.990320
# min               2016-09-19 00:15:34       0.850000       0.000000
# 25%        2017-09-20 20:57:27.500000      39.900000      13.080000
# 50%               2018-01-26 13:59:35      74.990000      16.260000
# 75%     2018-05-10 14:34:00.750000128     134.900000      21.150000
# max               2020-04-09 22:35:08    6735.000000     409.680000
# std                               NaN     183.633928      15.806405

# %%
order_items_df.sort_values(by="price", ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57300   8272b63d03f5f79c56e9e4120aec44ef              4
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
#
#                               product_id                         seller_id  \
# 3556    489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# 107841  1bdf5e6731585cf01aa8169c7028d6ad  ee27a8f15b1dded4d213a468ba4eb391
# 74336   a6492cc69376c469ab6f61d8f44de961  59417c56835dd8e2e72f91f809cd4092
# 11249   c3ed642d592594bb648ff4a04cee2747  59417c56835dd8e2e72f91f809cd4092
# ...                                  ...                               ...
# 57304   05b515fdc76e888aada3c6d66c201dff  2709af9587499e95e803a6498a5a56e9
# 57300   05b515fdc76e888aada3c6d66c201dff  2709af9587499e95e803a6498a5a56e9
# 48625   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 27652   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 87081   8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
#
#        shipping_limit_date    price  freight_value
# 3556   2017-02-16 20:37:36  6735.00         194.31
# 112233 2018-08-02 04:05:13  6729.00         193.21
# 107841 2017-06-15 02:45:17  6499.00         227.66
# 74336  2017-04-18 13:25:18  4799.00         151.34
# 11249  2017-05-09 15:50:15  4690.00          74.34
# ...                    ...      ...            ...
# 57304  2017-07-21 18:25:23     1.20           7.89
# 57300  2017-07-21 18:25:23     1.20           7.89
# 48625  2018-05-02 20:30:34     0.85          18.23
# 27652  2018-05-04 03:55:26     0.85          18.23
# 87081  2018-05-07 02:55:22     0.85          22.30
#
# [112650 rows x 7 columns]

# %% [markdown]
# ### Explore `order_payments_df`

# %%
order_payments_df.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 54539  9b065fb66bb55fb371de21a292a25d63                   1  credit_card
# 50798  a122cfd6bf1027781187a1fec2f24ba1                   1  credit_card
# 56589  0de1434ccb9861eaddb1c05cf3c7c0ec                   1  credit_card
# 5693   6ac9e7249ef5df977218e8251e151355                   1  credit_card
# 47675  d23b1afea718882b7c22f47dbb27a482                   1  credit_card
#
#        payment_installments  payment_value
# 54539                     2         102.03
# 50798                     2          99.90
# 56589                     1          59.61
# 5693                      1          65.71
# 47675                     2         139.48

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# count          103886.000000  103886.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean                2.853349     154.100380
# std                 2.687051     217.494064
# min                 0.000000       0.000000
# 25%                 1.000000      56.790000
# 50%                 1.000000     100.000000
# 75%                 4.000000     171.837500
# max                24.000000   13664.080000

# %%
order_payments_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52107  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34370  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41419  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49581  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 85539  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 43744  6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 62674  45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 19922  8bcbe01d44d147f901cd3192671144db                   4      voucher
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 77885  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
#
#        payment_installments  payment_value
# 52107                     1       13664.08
# 34370                     1        7274.88
# 41419                     8        6929.31
# 49581                     1        6922.21
# 85539                     1        6726.66
# ...                     ...            ...
# 43744                     1           0.00
# 62674                     1           0.00
# 19922                     1           0.00
# 94427                     1           0.00
# 77885                     1           0.00
#
# [103886 rows x 5 columns]

# %%
order_payments_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value": ["max", "min", "mean", "std"]
})
# Out:
#              order_id payment_value
#               nunique           max    min        mean         std
# payment_type
# boleto          19784       7274.88  11.62  145.034435  213.581061
# credit_card     76505      13664.08   0.01  163.319021  222.119311
# debit_card       1528       4445.50  13.38  142.570170  245.793401
# not_defined         3          0.00   0.00    0.000000    0.000000
# voucher          3866       3184.34   0.00   65.703354  115.519185

# %% [markdown]
# ### Explore `order_reviews_df`

# %%
order_reviews_df.sample(5)
# Out:
#                               review_id                          order_id  \
# 52731  90126cabc13d5190e1911de00158db59  c31c5506867767b7649a3833086c2925
# 32085  b1a6979a01d70c35bbf0b19c89959f6a  3323fd4055090e20288b12f59a77e9fb
# 17886  ca163a4be0d0c71a53abf7382fa16732  8b103650a25fb8cc322e23f2aabb44ef
# 61288  ff9af208ff39bc7d0ab29fc3baba4cf8  6145340f417b2ec892ce4c053d245a0f
# 31604  0402e811f8502142e207b1df7e0c54f8  2edcf6adbf3719366560d6863cb28799
#
#        review_score review_comment_title  \
# 52731             5                  NaN
# 32085             1                  NaN
# 17886             5                  NaN
# 61288             5                  NaN
# 31604             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 52731                                  Perfume excelente           2017-10-31
# 32085  Compei uma pingente e nunca chegou, comprei di...           2018-02-07
# 17886                                          Recomendo           2017-11-09
# 61288                                                NaN           2018-01-13
# 31604  Ficou faltando um kit do produto, os pendente ...           2018-05-16
#
#       review_answer_timestamp
# 52731     2017-10-31 17:50:09
# 32085     2018-02-08 08:41:17
# 17886     2017-11-12 00:39:50
# 61288     2018-01-15 19:55:15
# 31604     2018-05-16 17:24:11

# %%
feedback_time = order_reviews_df["review_answer_timestamp"] - order_reviews_df["review_creation_date"]
feedback_time = feedback_time.apply(lambda x: x.total_seconds())
order_reviews_df["feedback_time"] = round(feedback_time/86400)

# %%
order_reviews_df.sample(5)
# Out:
#                               review_id                          order_id  \
# 59339  0b230254983499bbe24dd28d09cbf955  24f937ccbe294a3f3d24859938e01915
# 89757  eb7b7741450a9570dab7725729afd238  c98c642afddadee451d6ca9822f297d9
# 84549  a180cd26d32f195f0024bc69098f7b46  6dca57240c5cb67c2673be12f538a2fc
# 98272  f1efbc48484d5f8cce4051aeaf62250d  b9895a352437ec0701eccabb55cc43ea
# 47286  58b4d30e8020de295eb64a3162abb472  ec28cd8095b8c6aa0d63cd0ff24c6cd3
#
#        review_score review_comment_title  \
# 59339             1                  NaN
# 89757             5                  NaN
# 84549             5           Excelente.
# 98272             4                  NaN
# 47286             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 59339  As bolsas são muito bonitas, mas verificando a...           2017-05-19
# 89757                                                NaN           2018-04-11
# 84549  Este fornecedor, parceiro das Lojas lannister ...           2018-08-03
# 98272                                                NaN           2018-04-24
# 47286                                                NaN           2018-02-10
#
#       review_answer_timestamp  feedback_time
# 59339     2017-05-22 11:48:12            3.0
# 89757     2018-04-14 05:20:15            3.0
# 84549     2018-08-05 05:44:45            2.0
# 98272     2018-04-26 18:18:38            3.0
# 47286     2018-02-12 21:55:07            3.0

# %%
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# count   99224.000000                11568                  40977
# unique           NaN                 4527                  36159
# top              NaN            Recomendo              Muito bom
# freq             NaN                  423                    230
# mean        4.086421                  NaN                    NaN
# min         1.000000                  NaN                    NaN
# 25%         4.000000                  NaN                    NaN
# 50%         5.000000                  NaN                    NaN
# 75%         5.000000                  NaN                    NaN
# max         5.000000                  NaN                    NaN
# std         1.347579                  NaN                    NaN
#
#                  review_creation_date        review_answer_timestamp  \
# count                           99224                          99224
# unique                            NaN                            NaN
# top                               NaN                            NaN
# freq                              NaN                            NaN
# mean    2018-01-12 20:49:23.948238336  2018-01-16 00:23:56.977938688
# min               2016-10-02 00:00:00            2016-10-07 18:32:28
# 25%               2017-09-23 00:00:00  2017-09-27 01:53:27.249999872
# 50%               2018-02-02 00:00:00     2018-02-04 22:41:47.500000
# 75%               2018-05-16 00:00:00     2018-05-20 12:11:21.500000
# max               2018-08-31 00:00:00            2018-10-29 12:27:35
# std                               NaN                            NaN
#
#         feedback_time
# count    99224.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         3.213658
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        519.000000
# std          9.904641

# %%
order_reviews_df.groupby(by="review_score").review_id.nunique().sort_values(ascending=False)
# Out:
# review_score
# 5    56910
# 4    19007
# 1    11282
# 3     8097
# 2     3114
# Name: review_id, dtype: int64

# %% [markdown]
# ### Explore `orders_df`

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 17451  756e696d1e7ff7fd6728f59e92e22651  82187afcec1f653bd7424ab915194a0a
# 96889  46ab5f4b3a88ae05be005f9736c0e9e6  1a455c3578447cae5fde99531bb7dc8d
# 63630  782bc6a39d1541304f6111016c820437  9426c0356c4a1e260aa701770196f3ce
# 23397  d2f7f741c41b156c60f31e9d119dd22e  beb96061489f7c042c033ae76990e106
# 80249  cc93f3b0bbc28bf5e1bd3ff40b4b2666  6a7add565bee8d10537837268f674a76
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 17451    delivered      2018-03-11 16:39:02 2018-03-11 17:20:30
# 96889    delivered      2018-01-10 19:48:48 2018-01-12 02:36:41
# 63630    delivered      2017-07-27 11:07:49 2017-07-28 11:10:15
# 23397    delivered      2018-01-10 13:50:43 2018-01-10 14:08:03
# 80249    delivered      2017-12-22 14:45:15 2017-12-22 14:58:24
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 17451          2018-03-12 17:42:09           2018-03-19 19:38:44
# 96889          2018-01-19 19:52:26           2018-02-01 18:26:05
# 63630          2017-07-31 19:07:11           2017-08-12 14:13:52
# 23397          2018-01-12 12:48:49           2018-01-18 17:24:28
# 80249          2017-12-28 19:58:03           2018-01-03 17:58:03
#
#       order_estimated_delivery_date
# 17451                    2018-04-12
# 96889                    2018-02-22
# 63630                    2017-08-22
# 23397                    2018-02-05
# 80249                    2018-01-22

# %%
orders_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_id, dtype: int64

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
estimate_time = orders_df["order_estimated_delivery_date"] - orders_df["order_delivered_carrier_date"]
estimate_time = estimate_time.apply(lambda x: x.total_seconds())
orders_df["estimate_time"] = round(estimate_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 72236  7229c37246dd5343775180438d13772b  5e9871527b49b68aaaf049bf6cfec670
# 27146  130e5f15b505062879273e8f199441d1  241a20babe281dff9201cd9abc43b96a
# 27425  6b2b0edb95053b55efeb09177b6510c3  1cd1bf3921c35dd04851354a26e28a5b
# 10207  dde57deff5c66be4e59c0da19696ea50  743033460f70e2683a86178ac4ef7351
# 17659  192de94c5d82086caf648552314731ad  3a1325eb0f3275e1e22b30c47a852633
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 72236    delivered      2018-06-11 17:33:45 2018-06-12 08:41:51
# 27146    delivered      2018-05-16 12:09:43 2018-05-16 12:39:15
# 27425    delivered      2017-06-24 19:17:09 2017-06-25 06:42:37
# 10207    delivered      2018-08-04 12:50:55 2018-08-04 13:05:14
# 17659    delivered      2018-04-20 09:31:43 2018-04-20 09:52:53
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 72236          2018-06-18 17:57:00           2018-06-25 20:12:22
# 27146          2018-05-17 13:51:00           2018-05-22 00:04:16
# 27425          2017-06-26 10:22:53           2017-07-22 11:36:47
# 10207          2018-08-09 15:57:00           2018-08-20 14:18:56
# 17659          2018-04-20 20:37:34           2018-04-23 18:24:34
#
#       order_estimated_delivery_date  delivery_time  estimate_time
# 72236                    2018-07-04            7.0           15.0
# 27146                    2018-05-30            4.0           12.0
# 27425                    2017-07-20           26.0           24.0
# 10207                    2018-08-22           11.0           12.0
# 17659                    2018-04-30            3.0            9.0

# %% [markdown]
# ### Explore `sellers_df`

# %%
sellers_df.sample(5)
# Out:
#                              seller_id  seller_zip_code_prefix   seller_city  \
# 2371  240b9776d844d37535668549a396af32                   24120       niteroi
# 2415  4ea2f12dbe91deeacd2c1e74f069a6e6                    2334     sao paulo
# 1547  96f7c797de9ca20efbe14545bed63eec                   14140     cravinhos
# 423   ceaec5548eefc6e23e6607c5435102e7                    3821     sao paulo
# 1108  d7f1cfc638473be93baedbfd02208016                   26112  belford roxo
#
#      seller_state
# 2371           RJ
# 2415           SP
# 1547           SP
# 423            SP
# 1108           RJ

# %%
sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %%
sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore `customers_df` & `orders_df`

# %% [markdown]
# #### Menggabungkan data `customers_df` dan `orders_df`

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delivery_time  estimate_time  \
# 0                    2017-10-18            6.0           13.0
# 1                    2018-08-13           12.0           17.0
# 2                    2018-09-04            9.0           26.0
# 3                    2017-12-15            9.0           22.0
# 4                    2018-02-26            2.0           11.0
#
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149
# 1  af07308b275d755c9edb36a90c618231                     47813
# 2  3a653a41f6f9fc3d2a113cf8398680e8                     75265
# 3  7c142cf63193a1473d2e66489a9ae977                     59296
# 4  72632f0f9dd73dfee390c9b22eb56dd6                      9195
#
#              customer_city customer_state
# 0                sao paulo             SP
# 1                barreiras             BA
# 2               vianopolis             GO
# 3  sao goncalo do amarante             RN
# 4              santo andre             SP

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15540
# rio de janeiro            6882
# belo horizonte            2773
# brasilia                  2131
# curitiba                  1521
# campinas                  1444
# porto alegre              1379
# salvador                  1245
# guarulhos                 1189
# sao bernardo do campo      938
# Name: order_id, dtype: int64

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore `order_items_df` dan `order_payments_df`

# %% [markdown]
# #### Menggabungkan data `order_items_df` dan `order_payments_df`

# %%
order_item_payment_df = pd.merge(
    left=order_items_df,
    right=order_payments_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_item_payment_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0 2017-09-19 09:45:35   58.90          13.29                 1.0  credit_card
# 1 2017-05-03 11:05:13  239.90          19.93                 1.0  credit_card
# 2 2018-01-18 14:48:30  199.00          17.87                 1.0  credit_card
# 3 2018-08-15 10:10:18   12.99          12.79                 1.0  credit_card
# 4 2017-02-13 13:57:51  199.90          18.14                 1.0  credit_card
#
#    payment_installments  payment_value
# 0                   2.0          72.19
# 1                   3.0         259.83
# 2                   5.0         216.87
# 3                   2.0          25.78
# 4                   3.0         218.04

# %% [markdown]
# #### Menggabungkan data `products_df` dan `product_category_name_translation`

# %%
product_category_name_df = pd.merge(
    left=products_df,
    right=product_category_name_translation_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_category_name_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#   product_name_lenght product_description_lenght product_photos_qty  \
# 0                40.0                      287.0                1.0
# 1                44.0                      276.0                1.0
# 2                46.0                      250.0                1.0
# 3                27.0                      261.0                1.0
# 4                37.0                      402.0                4.0
#
#   product_weight_g product_length_cm product_height_cm product_width_cm  \
# 0            225.0              16.0              10.0             14.0
# 1           1000.0              30.0              18.0             20.0
# 2            154.0              18.0               9.0             15.0
# 3            371.0              26.0               4.0             26.0
# 4            625.0              20.0              17.0             13.0
#
#   product_category_name_english
# 0                     perfumery
# 1                           art
# 2                sports_leisure
# 3                          baby
# 4                    housewares

# %% [markdown]
# #### Menggabungkan data `order_item_payment_df` dan `product_category_name_df`

# %%
order_product_df = pd.merge(
    left=order_item_payment_df,
    right=product_category_name_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_product_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0 2017-09-19 09:45:35   58.90          13.29                 1.0  credit_card
# 1 2017-05-03 11:05:13  239.90          19.93                 1.0  credit_card
# 2 2018-01-18 14:48:30  199.00          17.87                 1.0  credit_card
# 3 2018-08-15 10:10:18   12.99          12.79                 1.0  credit_card
# 4 2017-02-13 13:57:51  199.90          18.14                 1.0  credit_card
#
#    payment_installments  payment_value product_category_name  \
# 0                   2.0          72.19            cool_stuff
# 1                   3.0         259.83              pet_shop
# 2                   5.0         216.87      moveis_decoracao
# 3                   2.0          25.78            perfumaria
# 4                   3.0         218.04    ferramentas_jardim
#
#   product_name_lenght product_description_lenght product_photos_qty  \
# 0                58.0                      598.0                4.0
# 1                56.0                      239.0                2.0
# 2                59.0                      695.0                2.0
# 3                42.0                      480.0                1.0
# 4                59.0                      409.0                1.0
#
#   product_weight_g product_length_cm product_height_cm product_width_cm  \
# 0            650.0              28.0               9.0             14.0
# 1          30000.0              50.0              30.0             40.0
# 2           3050.0              33.0              13.0             33.0
# 3            200.0              16.0              10.0             15.0
# 4           3750.0              35.0              40.0             30.0
#
#   product_category_name_english
# 0                    cool_stuff
# 1                      pet_shop
# 2               furniture_decor
# 3                     perfumery
# 4                  garden_tools

# %%
order_product_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
# Out:
#                                order_id  payment_value
# product_category_name_english
# agro_industry_and_commerce          182      118730.61
# air_conditioning                    253       91170.66
# art                                 202       30992.93
# arts_and_craftmanship                23        2326.17
# audio                               350       60324.62
# ...                                 ...            ...
# stationery                         2311      317440.07
# tablets_printing_image               79       10042.93
# telephony                          4199      486882.05
# toys                               3886      619037.69
# watches_gifts                      5624     1429216.68
#
# [71 rows x 2 columns]

# %%
order_product_review_df = pd.merge(
    left=order_product_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_product_review_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0 2017-09-19 09:45:35   58.90          13.29                 1.0  credit_card
# 1 2017-05-03 11:05:13  239.90          19.93                 1.0  credit_card
# 2 2018-01-18 14:48:30  199.00          17.87                 1.0  credit_card
# 3 2018-08-15 10:10:18   12.99          12.79                 1.0  credit_card
# 4 2017-02-13 13:57:51  199.90          18.14                 1.0  credit_card
#
#    payment_installments  ...  product_height_cm product_width_cm  \
# 0                   2.0  ...                9.0             14.0
# 1                   3.0  ...               30.0             40.0
# 2                   5.0  ...               13.0             33.0
# 3                   2.0  ...               10.0             15.0
# 4                   3.0  ...               40.0             30.0
#
#   product_category_name_english                         review_id  \
# 0                    cool_stuff  97ca439bc427b48bc1cd7177abe71365
# 1                      pet_shop  7b07bacd811c4117b742569b04ce3580
# 2               furniture_decor  0c5b33dea94867d1ac402749e5438e8b
# 3                     perfumery  f4028d019cb58564807486a6aaf33817
# 4                  garden_tools  940144190dcba6351888cafa43f3a3a5
#
#   review_score review_comment_title  \
# 0          5.0                  NaN
# 1          4.0                  NaN
# 2          5.0                  NaN
# 3          4.0                  NaN
# 4          5.0                  NaN
#
#                               review_comment_message review_creation_date  \
# 0     Perfeito, produto entregue antes do combinado.           2017-09-21
# 1                                                NaN           2017-05-13
# 2  Chegou antes do prazo previsto e o produto sur...           2018-01-23
# 3                                                NaN           2018-08-15
# 4            Gostei pois veio no prazo determinado .           2017-03-02
#
#   review_answer_timestamp feedback_time
# 0     2017-09-22 10:57:03           1.0
# 1     2017-05-15 11:34:13           2.0
# 2     2018-01-23 16:06:31           1.0
# 3     2018-08-15 16:39:01           1.0
# 4     2017-03-03 10:54:59           1.0
#
# [5 rows x 27 columns]

# %%
order_product_review_df.groupby(by=["review_score", "product_category_name_english"]).agg({
    "payment_value": "sum"
})
# Out:
#                                             payment_value
# review_score product_category_name_english
# 1.0          agro_industry_and_commerce          49461.62
#              air_conditioning                    21445.84
#              art                                  5326.03
#              arts_and_craftmanship                 329.85
#              audio                                9721.85
# ...                                                   ...
# 5.0          stationery                         190025.17
#              tablets_printing_image               5086.48
#              telephony                          213607.41
#              toys                               381850.61
#              watches_gifts                      799401.49
#
# [340 rows x 1 columns]

# %%
order_product_review_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "review_score": "sum",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  review_score  payment_value
# product_category_name_english
# bed_bath_table                    10860       52606.0     1997726.12
# health_beauty                      8836       41151.0     1662963.59
# computers_accessories              6689       31902.0     1599481.06
# furniture_decor                    6449       34204.0     1443963.61
# watches_gifts                      5624       24753.0     1430553.48
# ...                                 ...           ...            ...
# flowers                              29         137.0        2213.01
# home_comfort_2                       24         102.0        1710.54
# cds_dvds_musicals                    12          65.0        1199.43
# fashion_childrens_clothes             8          36.0         785.67
# security_and_services                 2           5.0         324.51
#
# [71 rows x 3 columns]

# %% [markdown]
# #### Menggabungkan data `order_product_review_df` dan `orders_customers_df`

# %%
sales_df = pd.merge(
    left=order_product_review_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
sales_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0 2017-09-19 09:45:35   58.90          13.29                 1.0  credit_card
# 1 2017-05-03 11:05:13  239.90          19.93                 1.0  credit_card
# 2 2018-01-18 14:48:30  199.00          17.87                 1.0  credit_card
# 3 2018-08-15 10:10:18   12.99          12.79                 1.0  credit_card
# 4 2017-02-13 13:57:51  199.90          18.14                 1.0  credit_card
#
#    payment_installments  ...   order_approved_at order_delivered_carrier_date  \
# 0                   2.0  ... 2017-09-13 09:45:35          2017-09-19 18:34:16
# 1                   3.0  ... 2017-04-26 11:05:13          2017-05-04 14:35:00
# 2                   5.0  ... 2018-01-14 14:48:30          2018-01-16 12:36:48
# 3                   2.0  ... 2018-08-08 10:10:18          2018-08-10 13:28:00
# 4                   3.0  ... 2017-02-04 14:10:13          2017-02-16 09:46:09
#
#   order_delivered_customer_date order_estimated_delivery_date delivery_time  \
# 0           2017-09-20 23:43:48                    2017-09-29           1.0
# 1           2017-05-12 16:04:24                    2017-05-15           8.0
# 2           2018-01-22 13:19:16                    2018-02-05           6.0
# 3           2018-08-14 13:32:39                    2018-08-20           4.0
# 4           2017-03-01 16:42:31                    2017-03-17          13.0
#
#   estimate_time                customer_unique_id customer_zip_code_prefix  \
# 0           9.0  871766c5855e863f6eccc05f988b23cb                    28013
# 1          10.0  eb28e67c4c0b83846050ddfb8a35d051                    15775
# 2          19.0  3818d81c6709e39d06b2738a8d3a2474                    35661
# 3           9.0  af861d436cfc08b2c2ddefd0ba074622                    12952
# 4          29.0  64b576fb70d441e8f1b2d7d446e483c5                    13226
#
#            customer_city customer_state
# 0  campos dos goytacazes             RJ
# 1        santa fe do sul             SP
# 2          para de minas             MG
# 3                atibaia             SP
# 4        varzea paulista             SP
#
# [5 rows x 40 columns]

# %%
all_data_df = pd.merge(
    left=sales_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
all_data_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  payment_sequential payment_type  \
# 0 2017-09-19 09:45:35   58.90          13.29                 1.0  credit_card
# 1 2017-05-03 11:05:13  239.90          19.93                 1.0  credit_card
# 2 2018-01-18 14:48:30  199.00          17.87                 1.0  credit_card
# 3 2018-08-15 10:10:18   12.99          12.79                 1.0  credit_card
# 4 2017-02-13 13:57:51  199.90          18.14                 1.0  credit_card
#
#    payment_installments  ...  order_estimated_delivery_date delivery_time  \
# 0                   2.0  ...                     2017-09-29           1.0
# 1                   3.0  ...                     2017-05-15           8.0
# 2                   5.0  ...                     2018-02-05           6.0
# 3                   2.0  ...                     2018-08-20           4.0
# 4                   3.0  ...                     2017-03-17          13.0
#
#   estimate_time                customer_unique_id customer_zip_code_prefix  \
# 0           9.0  871766c5855e863f6eccc05f988b23cb                    28013
# 1          10.0  eb28e67c4c0b83846050ddfb8a35d051                    15775
# 2          19.0  3818d81c6709e39d06b2738a8d3a2474                    35661
# 3           9.0  af861d436cfc08b2c2ddefd0ba074622                    12952
# 4          29.0  64b576fb70d441e8f1b2d7d446e483c5                    13226
#
#            customer_city customer_state seller_zip_code_prefix    seller_city  \
# 0  campos dos goytacazes             RJ                  27277  volta redonda
# 1        santa fe do sul             SP                   3471      sao paulo
# 2          para de minas             MG                  37564  borda da mata
# 3                atibaia             SP                  14403         franca
# 4        varzea paulista             SP                  87900         loanda
#
#   seller_state
# 0           SP
# 1           SP
# 2           MG
# 3           SP
# 4           PR
#
# [5 rows x 43 columns]

# %%
all_data_df.groupby(by="seller_city").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                  order_id  payment_value
# seller_city
# sao paulo           24588     4269639.08
# ibitinga             6565     1076538.05
# curitiba             2722      660358.07
# itaquaquecetuba      1241      579187.43
# guarulhos            2071      511826.28
# ...                   ...            ...
# resende                 1          42.05
# jarinu                  1          38.37
# cascavael               1          37.09
# palotina                1          28.22
# macatuba                1          25.69
#
# [611 rows x 2 columns]

# %%
all_data_df.groupby(by="seller_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#               order_id  payment_value
# seller_state
# SP               70188    13448403.08
# PR                7673     1861222.48
# MG                7930     1571008.90
# RJ                4353     1101492.65
# SC                3667      888833.38
# RS                1989      562981.58
# BA                 569      368177.86
# DF                 824      137899.29
# PE                 406      124894.83
# GO                 463      112290.09
# ES                 318       78839.53
# MA                 392       52159.22
# CE                  91       25849.77
# MT                 137       23638.95
# PB                  36       20610.23
# RN                  51       13559.01
# MS                  49       10826.04
# RO                  14        5553.27
# PI                  12        3184.50
# SE                   9        2466.13
# PA                   8        1393.11
# AM                   3        1258.80
# AC                   1         299.84

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Bagaimana performa penjualan dan revenue perusahaan dalam bulan terakhir?

# %%
all_data_df.sample(5)
# Out:
#                                 order_id  order_item_id  \
# 96749   d0f9f41e51b973c669a8c5f4c629eda9              1
# 42343   5b6e82f76cdae6678ce541e6f72c9b01              1
# 115227  f97b2bdfbaca9c2f04722d8cbc8cc8a5              1
# 86567   bb3164e0236b64b580d475215f1004d2              1
# 37156   4fd59975900e997c6785ec9da06787aa              1
#
#                               product_id                         seller_id  \
# 96749   eac4543cfde63c7427a4659b8c907098  d91fb3b7d041e83b64a00a3edfb37e4f
# 42343   dd47440cb56de3ab674f9208ff0edc3e  3bdff180c7e1f6551a643b99c265a120
# 115227  054515fd15bc1a2029f10de97ffa9120  e9779976487b77c6d4ac45f75ec7afe9
# 86567   69d110cc75a123721c86bcfc77fa8afb  8a432f4e5b471f8da497d7dc517666e2
# 37156   4c88eca6c1faef5911374843849bd577  2bf6a2c1e71bbd29a4ad64e6d3c3629f
#
#        shipping_limit_date  price  freight_value  payment_sequential  \
# 96749  2018-06-07 19:35:42  153.5          18.95                 1.0
# 42343  2017-06-29 21:06:57   69.9          13.08                 1.0
# 115227 2018-08-13 18:45:20   43.0          18.40                 1.0
# 86567  2018-06-21 15:31:51   69.0          13.14                 1.0
# 37156  2018-06-29 19:54:11  744.0          13.90                 1.0
#
#        payment_type  payment_installments  ...  order_estimated_delivery_date  \
# 96749        boleto                   1.0  ...                     2018-07-18
# 42343   credit_card                   3.0  ...                     2017-07-07
# 115227  credit_card                   3.0  ...                     2018-08-24
# 86567   credit_card                   3.0  ...                     2018-07-11
# 37156   credit_card                   8.0  ...                     2018-07-26
#
#        delivery_time estimate_time                customer_unique_id  \
# 96749           11.0          46.0  6a4b9eb72b83befc39e5142f18549aa3
# 42343            1.0           9.0  1f80e2d0cc571920e312b26856aa7175
# 115227           6.0          13.0  91798cca876208ae649532488494682b
# 86567            3.0          21.0  08ebec5a1837c806bebe29c16c9736ca
# 37156            5.0          28.0  b80e73bfec2ccebcb2482a2dc89d4a0a
#
#        customer_zip_code_prefix     customer_city customer_state  \
# 96749                     96506  cachoeira do sul             RS
# 42343                      3432         sao paulo             SP
# 115227                    88915          maracana             SC
# 86567                      5686         sao paulo             SP
# 37156                     21735    rio de janeiro             RJ
#
#        seller_zip_code_prefix          seller_city seller_state
# 96749                   11704         praia grande           SP
# 42343                    4811            sao paulo           SP
# 115227                  11701         praia grande           SP
# 86567                   19042  presidente prudente           SP
# 37156                   28615        nova friburgo           RJ
#
# [5 rows x 43 columns]

# %%
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  delivery_time  estimate_time
# 0                    2017-10-18            6.0           13.0
# 1                    2018-08-13           12.0           17.0
# 2                    2018-09-04            9.0           26.0
# 3                    2017-12-15            9.0           22.0
# 4                    2018-02-26            2.0           11.0
